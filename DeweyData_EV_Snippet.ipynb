# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# data= '/content/drive/My Drive/DeweyData Extract/DeweyDataExtract_2025FEB05.parquet'
# Out:
# Mounted at /content/drive

# %%
# import polars as pl
import pandas as pd

df = pd.read_parquet('DeweyDataExtract_2025FEB05.parquet', engine='pyarrow')

df.head()
# Out:
#               PLACEKEY PARENT_PLACEKEY SAFEGRAPH_BRAND_IDS  \
# 0  222-222@8f3-fxx-pvz
# 1  zzw-222@8f4-ggp-2ff
# 2  226-223@8gn-24k-qvf
# 3  224-222@8gk-w8t-47q
# 4  zzw-222@8gm-s2p-k9f
#
#                        LOCATION_NAME BRANDS STORE_ID  \
# 0  Bay City Free Will Baptist Church
# 1        Red Springs Assembly Of God
# 2                 Stephen L Klimjack
# 3                William A McWhorter
# 4  Saint Clair Correctional Facility
#
#                                    TOP_CATEGORY               SUB_CATEGORY  \
# 0                       Religious Organizations    Religious Organizations
# 1                       Religious Organizations    Religious Organizations
# 2  Justice, Public Order, and Safety Activities                     Courts
# 3  Justice, Public Order, and Safety Activities                     Courts
# 4  Justice, Public Order, and Safety Activities  Correctional Institutions
#
#   NAICS_CODE   LATITUDE  ...  \
# 0     813110  30.778100  ...
# 1     813110  31.988419  ...
# 2     922110  32.359772  ...
# 3     922110  33.586196  ...
# 4     922140  33.743673  ...
#
#                               RELATED_SAME_DAY_BRAND  \
# 0  {"Exxon Mobil":16,"Circle K":9,"Circle K Gas":...
# 1  {"Exxon Mobil":9,"Dollar General":3,"Jackson H...
# 2  {"Hunt Brothers Pizza":28,"Publix Pharmacy":28...
# 3  {"Publix Pharmacy":35,"Publix Super Markets":3...
# 4  {"Subway":49,"Jackson Hewitt Tax Service":39,"...
#
#                             RELATED_SAME_MONTH_BRAND  \
# 0  {"Exxon Mobil":42,"Circle K":29,"Firehouse Sub...
# 1  {"Exxon Mobil":12,"Chevron":9,"Dollar General"...
# 2  {"CVS Pharmacy":103,"McDonald's":103,"Hunt Bro...
# 3  {"Walmart":145,"Walmart Pharmacy":145,"Walmart...
# 4  {"Subway":125,"Walmart":113,"Walmart Pharmacy"...
#
#                                   POPULARITY_BY_HOUR  \
# 0  [14,14,14,14,14,14,18,14,14,14,20,18,14,14,14,...
# 1  [0,0,0,0,0,0,1,7,1,6,0,1,6,2,3,16,2,7,1,3,2,3,...
# 2  [4,4,4,4,4,4,4,4,16,6,19,30,19,42,27,24,19,4,6...
# 3  [13,0,0,19,0,0,0,10,30,24,18,45,32,27,28,23,40...
# 4  [125,61,64,58,72,80,64,96,141,158,150,120,128,...
#
#                                    POPULARITY_BY_DAY              DEVICE_TYPE  \
# 0  {"Monday":5,"Tuesday":0,"Wednesday":13,"Thursd...  {"ios":16,"android":10}
# 1  {"Monday":6,"Tuesday":11,"Wednesday":11,"Thurs...                {"ios":6}
# 2  {"Monday":30,"Tuesday":29,"Wednesday":29,"Thur...  {"android":75,"ios":47}
# 3  {"Monday":45,"Tuesday":46,"Wednesday":52,"Thur...  {"android":88,"ios":57}
# 4  {"Monday":153,"Tuesday":131,"Wednesday":123,"T...  {"android":95,"ios":46}
#
#   NORMALIZED_VISITS_BY_STATE_SCALING NORMALIZED_VISITS_BY_REGION_NAICS_VISITS  \
# 0                              683.0                                 0.002153
# 1                              684.0                                 0.002268
# 2                             1984.0                                 0.054136
# 3                             3676.0                                 0.110955
# 4                             9272.0                                 0.304648
#
#   NORMALIZED_VISITS_BY_REGION_NAICS_VISITORS  \
# 0                                   0.002514
# 1                                   0.002657
# 2                                   0.079283
# 3                                   0.160743
# 4                                   0.324560
#
#   NORMALIZED_VISITS_BY_TOTAL_VISITS NORMALIZED_VISITS_BY_TOTAL_VISITORS
# 0                          0.000020                            0.000171
# 1                          0.000020                            0.000171
# 2                          0.000056                            0.000489
# 3                          0.000106                            0.000914
# 4                          0.000264                            0.002296
#
# [5 rows x 53 columns]
